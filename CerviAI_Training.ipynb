# %%
import os
import json
import cv2
import shutil
import random
from tqdm import tqdm

# %%
import tensorflow as tf

print("TensorFlow:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# TensorFlow: 2.16.2
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import json
import os
import cv2
import matplotlib.pyplot as plt

from collections import Counter

# %%
DATA_ROOT = "riva_1.0/raw"
ANNOTATION_PATH = os.path.join(DATA_ROOT, "annotations", "annotations.json")

print(ANNOTATION_PATH)
print(os.path.exists(ANNOTATION_PATH))
# Out:
# riva_1.0/raw/annotations/annotations.json
# True

# %%
with open(ANNOTATION_PATH) as f:
    data = json.load(f)

print("Number of annotated images:", len(data))
# Out:
# Number of annotated images: 959

# %%
IMAGES_DIR = os.path.join(DATA_ROOT, "images")

print("Images folder exists:", os.path.exists(IMAGES_DIR))
# Out:
# Images folder exists: True

# %%
# List all image files in the directory
image_files = [
    f for f in os.listdir(IMAGES_DIR)
    if f.lower().endswith((".png", ".jpg", ".jpeg", ".tif"))
]

print("Total number of images:", len(image_files))
# Out:
# Total number of images: 959

# %% [markdown]
# Step 1: Load annotations again (clean separation)

# %%
import json
import os
from collections import defaultdict, Counter

DATA_ROOT = "raw/riva_1.0"
ANNOTATION_PATH = os.path.join(DATA_ROOT, "annotations", "annotations.json")

with open(ANNOTATION_PATH, "r") as f:
    annotations = json.load(f)

print("Loaded images:", len(annotations))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 8
#       5 DATA_ROOT = "raw/riva_1.0"
#       6 ANNOTATION_PATH = os.path.join(DATA_ROOT, "annotations", "annotations.json")
# ----> 8 with open(ANNOTATION_PATH, "r") as f:
#       9     annotations = json.load(f)
#      11 print("Loaded images:", len(annotations))
#
# File ~/Downloads/CerviAI/cerviai_env/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# ...
